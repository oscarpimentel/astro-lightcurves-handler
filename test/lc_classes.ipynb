# %%
import sys
sys.path.append('..')
sys.path.append('../..')

# %%
# %load_ext autoreload
# %autoreload 2
from src.data_classes import LCO
from src.plots import plot_lightcurve
import matplotlib.pyplot as plt
import numpy as np

band_names = ['g', 'r']
lcobj = LCO()
lcobj.add_b('g', np.array([2,4,8,10]), np.array([7,8,9,0]), np.array([0,0,0,1]))
lcobj.add_b('r', np.array([5,6,9,11,12,13,14,16]), np.array([1,2,3,4,4,5,4,5]), np.array([1,5,6,0,0,1,0,1]))

fig, ax = plt.subplots(1, 1, figsize=(10,3))
for kb,b in enumerate(band_names):
    plot_lightcurve(ax, lcobj, b)
    
day_offset = lcobj.reset_day_offset_serial()
fig, ax = plt.subplots(1, 1, figsize=(10,3))
for kb,b in enumerate(band_names):
    plot_lightcurve(ax, lcobj, b)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
from src.data_classes import LCO
import numpy as np

lcobj2 = lcobj.copy()
lcobj2.r.set_log('obs')
lcobj2.r.add_day_noise_uniform(5) # add day noise
lcobj2.r.add_obs_noise_gaussian(1) # add obs noise

fig, ax = plt.subplots(1, 1, figsize=(10,3))
for kb,b in enumerate(band_names):
    plot_lightcurve(ax, lcobj2, b)
    
ax.plot(lcobj2.r.log_obs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
from src.data_classes import LCO
import numpy as np

lcobj2 = lcobj.copy()
lcobj2.r.set_diff('days')
print(lcobj2.r.d_days)
lcobj2.r.apply_downsampling(0.5) # apply_downsampling
print(lcobj2.r.d_days)

fig, ax = plt.subplots(1, 1, figsize=(10,3))
for kb,b in enumerate(band_names):
    plot_lightcurve(ax, lcobj2, b)
    
#day_offset = lcobj2.reset_day_offset_serial()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [0. 1. 3. 2. 1. 1. 1. 2.]
# [0. 3. 3. 1. 1.]

# %%
lco.g.get_x()

# %%
lco.r.get_x()

# %%
lco.get_onehot()

# %%
lco.get_x()

# %%
lco.set_diff('days')
lco.get_custom_x(['days', 'obs', 'ddays'])

# %%
lco.get_custom_x(['days', 'obs', 'ddays'])

# %% [markdown]
# # max len

# %%
lco.get_b('r').get_x()
