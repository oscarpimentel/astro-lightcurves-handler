# %%
import pandas as pd
import numpy as np

sn = pd.read_csv('SNe_more_5.csv')
#sn = sn.drop_duplicates(subset=['objectId','classALeRCE'])
p_objs = list(set(sn['objectId'].values))
print(sn.info())
print(sn['magpsf_corr'].values)
v,c = np.unique(sn['classALeRCE'].values, return_counts=1)
print(v,c)
print(sum(c))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33904 entries, 0 to 33903
# Data columns (total 8 columns):
# objectId         33904 non-null object
# classALeRCE      33904 non-null object
# mjd              33904 non-null float64
# fid              33904 non-null float64
# ra               33904 non-null float64
# dec              33904 non-null float64
# magpsf_corr      33904 non-null float64
# sigmapsf_corr    33904 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 2.1+ MB
# None
# [17.82229033 18.34010486 18.19809356 ... 17.49951984 17.48990411
#  17.40502215]
# ['SLSN' 'SNII' 'SNIIb' 'SNIIn' 'SNIa' 'SNIbc'] [ 1052  6721   204  2043 22593  1291]
# 33904

# %%
detections_df = pd.read_parquet(f'{load_rootdir}/{survey_name}/detections_with_xmatch')
labels_df = pd.read_csv(f'{load_rootdir}/{survey_name}/dfcrossmatches_prioritized_v7.0.1.csv')

# %%
df = detections_df.loc[['ZTF18adbktyj','ZTF19aatevrp']]
print(labels_df[labels_df['oid'].isin(['ZTF18adbktyj','ZTF19aatevrp'])])
df = df.drop_duplicates()
df = df[(df['isdiffpos']==1)]
df

# %%
sn
# Out:
#            objectId classALeRCE           mjd  fid          ra        dec  \
# 0      ZTF18abshezu        SLSN  58432.242986  1.0  359.324774 -15.631484
# 1      ZTF18abshezu        SLSN  58382.252639  1.0  359.324737 -15.631466
# 2      ZTF18abshezu        SLSN  58390.314410  1.0  359.324751 -15.631509
# 3      ZTF18abshezu        SLSN  58469.148808  1.0  359.324809 -15.631543
# 4      ZTF18abshezu        SLSN  58423.240336  1.0  359.324775 -15.631466
# 5      ZTF18abshezu        SLSN  58378.335660  1.0  359.324781 -15.631454
# 6      ZTF18abshezu        SLSN  58372.400995  1.0  359.324785 -15.631494
# 7      ZTF18abshezu        SLSN  58363.334850  1.0  359.324767 -15.631524
# 8      ZTF18abshezu        SLSN  58438.211250  1.0  359.324839 -15.631445
# 9      ZTF18abshezu        SLSN  58435.189468  1.0  359.324780 -15.631488
# 10     ZTF18abshezu        SLSN  58369.329861  1.0  359.324758 -15.631505
# 11     ZTF18abshezu        SLSN  58429.230718  1.0  359.324760 -15.631470
# ...

# %%
sn.loc['ZTF18acaeous']
sn.loc['ZTF18acdvvgx']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'ZTF18acaeous'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-071f9b7668dc> in <module>
# ----> 1 sn.loc['ZTF18acaeous']
#       2 sn.loc['ZTF18acdvvgx']
#
# ...

# %%
len(p_objs)
p_objs
# Out:
# ['ZTF19ababigc',
#  'ZTF19ablpfhz',
#  'ZTF20aaxccrm',
#  'ZTF19aarinmw',
#  'ZTF20aadcbux',
#  'ZTF19abpzuzd',
#  'ZTF20abbbsfs',
#  'ZTF18acyawjf',
#  'ZTF19aauhwbp',
#  'ZTF20aayknbc',
#  'ZTF19acjwdnu',
#  'ZTF19abjslyw',
#  'ZTF19aampqcq',
#  'ZTF19aaocbes',
#  'ZTF19aalbrgu',
#  'ZTF18acbwavp',
#  'ZTF19abujhgm',
#  'ZTF18abdfwcy',
#  'ZTF20aafcmfi',
#  'ZTF20aaznpor',
#  'ZTF19aalcwjt',
#  'ZTF18aaqkcso',
#  'ZTF19abyhxzp',
#  'ZTF18abmxmsv',
#  'ZTF18abeajml',
#  'ZTF20aamoaim',
#  'ZTF19acgaxej',
#  'ZTF18abuhyjv',
#  'ZTF20aavqfli',
#  'ZTF18abfzhct',
#  'ZTF19abqrxhy',
#  'ZTF19abcvrpm',
#  'ZTF19abwswzb',
#  'ZTF19abfiqjg',
#  'ZTF19aanfukh',
#  'ZTF20aazqiel',
#  'ZTF18acpefgk',
#  'ZTF19abqanpy',
#  'ZTF19acdsqir',
#  'ZTF19aayrjnf',
#  'ZTF19abqgtqo',
#  'ZTF19acxovyh',
#  'ZTF18acqpqph',
#  'ZTF18abhhxcp',
#  'ZTF19ackjvtl',
#  'ZTF18aawjywv',
#  'ZTF20abefbnz',
#  'ZTF18absoomk',
#  'ZTF18acyxnyw',
#  'ZTF18acslbve',
#  'ZTF18abjtgdo',
#  'ZTF19adajivt',
# ...

# %%
o_objs = ['ZTF19abqysic', 'ZTF20aabqiav', 'ZTF19aanesgt', 'ZTF20aanadlu', 'ZTF19abpbqor', 'ZTF18abrxwon', 'ZTF19abrirdm', 'ZTF19aavbkly', 'ZTF20aadyukn', 'ZTF20abdajyr', 'ZTF18acclexy', 'ZTF19abujuex', 'ZTF19aaozplq', 'ZTF18abmdpwe', 'ZTF19aaokist', 'ZTF18aboebre', 'ZTF18ablqjul', 'ZTF18acbwxcc', 'ZTF19aauivtj', 'ZTF19abnagzk', 'ZTF19aamowaf', 'ZTF19aayjhpg', 'ZTF20aadvunl', 'ZTF19aamhhae', 'ZTF20aautzif', 'ZTF20aaporoa', 'ZTF19acduqvr', 'ZTF19abzmpvb', 'ZTF20aaulzvl', 'ZTF18acefhxx', 'ZTF18abxygvv', 'ZTF18acrxppd', 'ZTF20aazkxcw', 'ZTF19aagkfvq', 'ZTF20aayxkqy', 'ZTF18aaermez', 'ZTF18aczenvx', 'ZTF19acjwqvo', 'ZTF20aafrihv', 'ZTF20aambbfn', 'ZTF20aadcitq', 'ZTF18acbwtng', 'ZTF19abcncdg', 'ZTF18aaqkdwf', 'ZTF18acbvgry', 'ZTF19abzvyew', 'ZTF20aavqfli', 'ZTF18aahatvc', 'ZTF19acqdato', 'ZTF19aahsnmq', 'ZTF19aaqtyku', 'ZTF19abakjao', 'ZTF19abhcefa', 'ZTF19aafljiq', 'ZTF19abqsmns', 'ZTF20aazpaki', 'ZTF18aawrvit', 'ZTF19aajxwnz', 'ZTF19abfvhlx', 'ZTF19aamhhey', 'ZTF18aadzfso', 'ZTF19abgiwkt', 'ZTF19aardunx', 'ZTF19acbkczc', 'ZTF19abdyawn', 'ZTF20aaezaxk', 'ZTF19adcecwu', 'ZTF19abegizf', 'ZTF19acypppb', 'ZTF19aawafvn', 'ZTF18adcdcrd', 'ZTF19abocled', 'ZTF19abzmpku', 'ZTF19aculczm', 'ZTF18acusrws', 'ZTF20aadxvfj', 'ZTF19acbnhkd', 'ZTF19abzzhsa', 'ZTF19abpbbxx', 'ZTF19acgzzea', 'ZTF18aarcypa', 'ZTF19abattvp', 'ZTF20aalrqbu', 'ZTF20aauvmix', 'ZTF19ablqnuw', 'ZTF19aajxhwa', 'ZTF19acardcs', 'ZTF20aauwjmw', 'ZTF20aaesewy', 'ZTF19aavnxwj', 'ZTF18aaybfsd', 'ZTF18acrhehl', 'ZTF20aammtwx', 'ZTF19abvhkst', 'ZTF20aahpxzz', 'ZTF19aalsnbp', 'ZTF19aamqebl', 'ZTF20aamenwg', 'ZTF18acdwazf', 'ZTF19adajivt', 'ZTF20aafrjqw', 'ZTF19aavhblr', 'ZTF19aaezwmr', 'ZTF19aartuli', 'ZTF20aahkgcz', 'ZTF20aamknna', 'ZTF18acefuhk', 'ZTF18abfdupq', 'ZTF18acqyvag', 'ZTF20aaycmhl', 'ZTF19aczjsqn', 'ZTF19abjioie', 'ZTF20aanrdek', 'ZTF18abqjvyl', 'ZTF19aaileug', 'ZTF18aarwxum', 'ZTF19aafmwhv', 'ZTF19ablfcjr', 'ZTF19abcndvf', 'ZTF19abrmlxu', 'ZTF20abccixp', 'ZTF19acxyucu', 'ZTF19abkfxfb', 'ZTF20aahaxjl', 'ZTF19achajnc', 'ZTF19abglmpf', 'ZTF19abdkgns', 'ZTF20aaxccrm', 'ZTF19aatgwhs', 'ZTF19aamgjtz', 'ZTF19abvgnxg', 'ZTF19abnmnrz', 'ZTF18aazixbw', 'ZTF19acblhxc', 'ZTF18acyxnyw', 'ZTF18acqsqrg', 'ZTF19aavrcew', 'ZTF19abqgtqo', 'ZTF19abgjlef', 'ZTF19acdxlns', 'ZTF19aaneugz', 'ZTF19abhdlxp', 'ZTF19abxjrge', 'ZTF19acmdpyr', 'ZTF20aabqiti', 'ZTF18adbacau', 'ZTF20aanadof', 'ZTF20abbblms', 'ZTF20aaerqjd', 'ZTF19aaupkrl', 'ZTF18abvejqt', 'ZTF18aarikzk', 'ZTF19aarmznp', 'ZTF19aclobbu', 'ZTF19acjfhom', 'ZTF19abfiqjg', 'ZTF18abeajml', 'ZTF18aalxmaq', 'ZTF19abkdrir', 'ZTF19aangier', 'ZTF18abqbuaj', 'ZTF18acbvbox', 'ZTF19aawtqdv', 'ZTF20aaxunbm', 'ZTF20aattqcv', 'ZTF20aazhyrs', 'ZTF18abkhcrj', 'ZTF19acdjiml', 'ZTF20abeeyrs', 'ZTF19aaumvig', 'ZTF19acygbye', 'ZTF20abeewmw', 'ZTF18abrfchj', 'ZTF18abrlljc', 'ZTF18abetewu', 'ZTF20aaowuim', 'ZTF19acfxbki', 'ZTF19aayrjnf', 'ZTF20aayjyhp', 'ZTF18abdfaqi', 'ZTF20aafsnpp', 'ZTF18aavsilo', 'ZTF20aaetrle', 'ZTF18aarlukc', 'ZTF18acafztq', 'ZTF19abucwzt', 'ZTF19aaluprf', 'ZTF19abfwdqv', 'ZTF20aasfhia', 'ZTF20aahirqq', 'ZTF18acrgunw', 'ZTF19abcejoa', 'ZTF19aajwkbb', 'ZTF19aarfnto', 'ZTF18abcpmwh', 'ZTF18accnbgw', 'ZTF19aanirdx', 'ZTF19abpztlw', 'ZTF19abzzhgx', 'ZTF18abtteyy', 'ZTF19ackjjwf', 'ZTF18aaqkcso', 'ZTF18abcxyjp', 'ZTF18acwwmry', 'ZTF18abmxdhb', 'ZTF20aaerxsd', 'ZTF19aauqywe', 'ZTF18acvhggp', 'ZTF19acfmwlh', 'ZTF18aceathd', 'ZTF19acyqwlm', 'ZTF19aavsahh', 'ZTF19acbwouf', 'ZTF18abeamgv', 'ZTF20aaqshoz', 'ZTF19acxozhr', 'ZTF19abdznxo', 'ZTF19acxolhu', 'ZTF20aawxpru', 'ZTF18aczqzrj', 'ZTF19abtnbtt', 'ZTF18abmxahs', 'ZTF20abdxuew', 'ZTF20aaznoxg', 'ZTF18adacoaj', 'ZTF20aazewhe', 'ZTF20aaszzez', 'ZTF20aafckit', 'ZTF19acgqjln', 'ZTF19aarnqys', 'ZTF18acrwheu', 'ZTF19aavqotz', 'ZTF18abkjnqy', 'ZTF20abcidhc', 'ZTF19acifuyf', 'ZTF18accjecm', 'ZTF19abcvrpm', 'ZTF20aattqle', 'ZTF19abvjdfc', 'ZTF19abjgdko', 'ZTF19aapfktd', 'ZTF20aagzqsb', 'ZTF18abdfwur', 'ZTF20aauwrod', 'ZTF20aattrkw', 'ZTF20abchhuw', 'ZTF20abedyov', 'ZTF19abqyoxj', 'ZTF19aatgznl', 'ZTF19aceqxtg', 'ZTF19aadnmgf', 'ZTF19abqmpti', 'ZTF18abslpjy', 'ZTF18acnbgrb', 'ZTF19acbpxwt', 'ZTF20abafzxx', 'ZTF18aaxdrjn', 'ZTF19abkrbjt', 'ZTF19acrenwk', 'ZTF18abeyqpr', 'ZTF19aaknvuh', 'ZTF19aczllns', 'ZTF18acvwbos', 'ZTF19abaosan', 'ZTF19abacxwt', 'ZTF19abrcpnj', 'ZTF18acbvahw', 'ZTF18abdrmin', 'ZTF19aamgokq', 'ZTF19aamtwwv', 'ZTF19aalvdeu', 'ZTF19aanfukh', 'ZTF19abhjhes', 'ZTF18aaqkjuw', 'ZTF20aavcvrm', 'ZTF18abmxfrc', 'ZTF19aclofmz', 'ZTF18acusbdy', 'ZTF19acbkyma', 'ZTF19aclhnkd', 'ZTF19abegxob', 'ZTF19aczlldp', 'ZTF19aawnqoj', 'ZTF18abdbuty', 'ZTF19abctxhf', 'ZTF20aapadwx', 'ZTF20aalcyih', 'ZTF18aavqdyq', 'ZTF18aacdbzx', 'ZTF18ablwgop', 'ZTF20abatfzl', 'ZTF19ablekwo', 'ZTF18abtvgxv', 'ZTF20abctyza', 'ZTF19aauitks', 'ZTF18aasdted', 'ZTF18aaoxryq', 'ZTF18abcvush', 'ZTF19abgppki', 'ZTF18abuqugw', 'ZTF19abdduix', 'ZTF18aaxkqgy', 'ZTF19aaeoqst', 'ZTF19aauhwbp', 'ZTF19adaxzax', 'ZTF18aaxcxih', 'ZTF19ablpnmk', 'ZTF19abxfunp', 'ZTF19acfsqjx', 'ZTF18accnmri', 'ZTF20aamdsjv', 'ZTF19aasmkhn', 'ZTF20aaurfhs', 'ZTF19abimlck', 'ZTF18acbwxou', 'ZTF19aawmkja', 'ZTF19abpavsn', 'ZTF20abajdvf', 'ZTF18abtogdl', 'ZTF19aacqeai', 'ZTF20aacexgb', 'ZTF20aavrzha', 'ZTF20aagfjlj', 'ZTF19aawupxb', 'ZTF19aaflnii', 'ZTF19aaxfzao', 'ZTF19abuclhk', 'ZTF20abawtpy', 'ZTF19aaraxhh', 'ZTF18acurqaw', 'ZTF19aaxhysx', 'ZTF19adbmwto', 'ZTF18aczebty', 'ZTF20aalrptc', 'ZTF18abmnrgb', 'ZTF18acsxvrp', 'ZTF20aamttni', 'ZTF18acsyanq', 'ZTF20aaljgcp', 'ZTF20aatxryt', 'ZTF19aboqbjz', 'ZTF19aanpcep', 'ZTF18acuqskr', 'ZTF18abuiknd', 'ZTF19acechlg', 'ZTF18absliyc', 'ZTF19aavnwxf', 'ZTF19abclykm', 'ZTF19aaxibpz', 'ZTF20aalkfui', 'ZTF19accmboe', 'ZTF20abefbpl', 'ZTF18acdvvgx', 'ZTF20aazqiel', 'ZTF18adalarn', 'ZTF20aahdwze', 'ZTF20aanvliy', 'ZTF19acomwca', 'ZTF19aanmeyw', 'ZTF19abimkwn', 'ZTF18absoomk', 'ZTF18acfwmqj', 'ZTF19adcdrng', 'ZTF19acbjlnt', 'ZTF19abwaohs', 'ZTF19aayqait', 'ZTF19abjbtbm', 'ZTF19aaeicsm', 'ZTF20aaurjbj', 'ZTF19acordoi', 'ZTF20aahapsq', 'ZTF18aasxvsg', 'ZTF20aawgrcu', 'ZTF20aacbgvj', 'ZTF18acdwohd', 'ZTF18abkifng', 'ZTF20aamcvyp', 'ZTF18absbgqd', 'ZTF18abhxidv', 'ZTF19aaycomi', 'ZTF18acsxpmp', 'ZTF19acblqjf', 'ZTF20aawihxz', 'ZTF19aatgrxv', 'ZTF20aawoojh', 'ZTF19aadnxbh', 'ZTF19acngsnc', 'ZTF20aamgdkb', 'ZTF18acrdlrp', 'ZTF18acbwxgn', 'ZTF20aayxdse', 'ZTF18abhbqbh', 'ZTF19aanbfaw', 'ZTF18aczeesl', 'ZTF20aacbtgq', 'ZTF18aapaohn', 'ZTF19aanijpu', 'ZTF18aawmxdx', 'ZTF19abqhobb', 'ZTF19abitbcj', 'ZTF19aailltc', 'ZTF20aadcdzj', 'ZTF20aayubpi', 'ZTF19ablrkfz', 'ZTF20abeldyn', 'ZTF19abrdnty', 'ZTF19aarinmw', 'ZTF20aaevbvv', 'ZTF18abcrzfz', 'ZTF19acgdfjt', 'ZTF18acbwaxk', 'ZTF18abcptmt', 'ZTF19aamrais', 'ZTF19acaiylt', 'ZTF20aavptjf', 'ZTF20abfqeef', 'ZTF19acbmojx', 'ZTF20aafwbcs', 'ZTF18acmxkzj', 'ZTF19ablfaey', 'ZTF19aarlefl', 'ZTF20aavnnzx', 'ZTF18abmxmsv', 'ZTF18acurlbt', 'ZTF19aawlgne', 'ZTF18aauhxce', 'ZTF19abkdeae', 'ZTF19acgbzam', 'ZTF18acqsztr', 'ZTF20aaynrrh', 'ZTF19acjurot', 'ZTF19acbihyi', 'ZTF18adalgmc', 'ZTF18aajkivu', 'ZTF18acbxmvy', 'ZTF20abbrptu', 'ZTF20abaslyx', 'ZTF19acaqqxo', 'ZTF19aanovps', 'ZTF19aazfvhh', 'ZTF19acckggd', 'ZTF19aamhhiz', 'ZTF18aaykjei', 'ZTF19abuazly', 'ZTF19aariwfe', 'ZTF19abgfrbl', 'ZTF18acptgzz', 'ZTF19aampqcq', 'ZTF19abtsrup', 'ZTF20abcwuwg', 'ZTF18abskove', 'ZTF20aagloch', 'ZTF19aceuacu', 'ZTF19adbricc', 'ZTF18abvsvjs', 'ZTF18acbwaax', 'ZTF20aawmcrd', 'ZTF19ablfdwt', 'ZTF19aavnwtf', 'ZTF19aafncsv', 'ZTF19aapfnym', 'ZTF20aavrukn', 'ZTF19abqanpy', 'ZTF19aanmdsr', 'ZTF18acxyarg', 'ZTF18abwkrbl', 'ZTF19abajxet', 'ZTF19aamvape', 'ZTF19aclkbqc', 'ZTF19abuhlxk', 'ZTF19abzrjrg', 'ZTF19aatgrxl', 'ZTF19aanxosu', 'ZTF18aawjywv', 'ZTF20abedydu', 'ZTF19aanxrkt', 'ZTF19aanfyey', 'ZTF19abpgggu', 'ZTF20aaghnxd', 'ZTF19abplfxs', 'ZTF19aauisdr', 'ZTF18acrlmvt', 'ZTF18acslbve', 'ZTF18aavjcpf', 'ZTF20aalmeaj', 'ZTF19abhztqq', 'ZTF18abncimo', 'ZTF19ackjnuq', 'ZTF19abpbopt', 'ZTF20aamttiw', 'ZTF19aalxcyo', 'ZTF19aabyuze', 'ZTF18acspjqd', 'ZTF20aafcnem', 'ZTF19abfvpkq', 'ZTF19acbrzzr', 'ZTF18acchzkf', 'ZTF19aaocbes', 'ZTF20aazpphr', 'ZTF20aaxcbvg', 'ZTF18abdrbqp', 'ZTF18abpamut', 'ZTF18abvxoty', 'ZTF19abozuxh', 'ZTF18acnnevs', 'ZTF20aaflaug', 'ZTF20aabrydh', 'ZTF18acgvgiq', 'ZTF19abdqaao', 'ZTF20abeeahl', 'ZTF18ablrljh', 'ZTF19abbvzgr', 'ZTF18aawpwlf', 'ZTF18abfzixe', 'ZTF18abvzdvj', 'ZTF19aaugaam', 'ZTF19aaqtcmy', 'ZTF19abdjsss', 'ZTF18aceexmi', 'ZTF18aavnxar', 'ZTF19abjibet', 'ZTF18abokpvh', 'ZTF20aammbrw', 'ZTF20aaybqae', 'ZTF20abehvas', 'ZTF19abpypvc', 'ZTF19aajwhse', 'ZTF19abeytzv', 'ZTF19abeloei', 'ZTF19acftclq', 'ZTF20aavynba', 'ZTF18abdkkwa', 'ZTF18aakkrjm', 'ZTF19aapvogv', 'ZTF18abrzeym', 'ZTF18abimhfu', 'ZTF19abpnrrf', 'ZTF19aanetjx', 'ZTF20aafcmfi', 'ZTF19acihfxz', 'ZTF19acgcshq', 'ZTF20aattqye', 'ZTF17aadlxmv', 'ZTF20aaxahpk', 'ZTF18aaxwjmp', 'ZTF19abqjypm', 'ZTF19aaxffum', 'ZTF19abgcbey', 'ZTF20aazquhc', 'ZTF19aallvor', 'ZTF19acoaoty', 'ZTF19aawtnqd', 'ZTF20aamqslk', 'ZTF19aaputrv', 'ZTF20aaaxerd', 'ZTF19aanlekq', 'ZTF18abdkimx', 'ZTF19abiztut', 'ZTF18abespgb', 'ZTF19abqqrib', 'ZTF19abxdnzt', 'ZTF19abpzuzd', 'ZTF19aarfyvc', 'ZTF20aazgtmp', 'ZTF20aavtdxj', 'ZTF18abeaipj', 'ZTF19acdsqir', 'ZTF18acuscgc', 'ZTF19acbpqvc', 'ZTF18acnbpkq', 'ZTF19aatevrp', 'ZTF19acftfst', 'ZTF18aaizerg', 'ZTF20aauzoca', 'ZTF18aatyqds', 'ZTF19acpgaet', 'ZTF18adazbol', 'ZTF18acrcogn', 'ZTF19aazpvdy', 'ZTF19adcfsad', 'ZTF19aaqxosb', 'ZTF19abipmfl', 'ZTF18aayivxm', 'ZTF19abhphah', 'ZTF18acvwhaz', 'ZTF18abffyqp', 'ZTF19adajqwl', 'ZTF20aadxcsc', 'ZTF19abctnpk', 'ZTF19abyjgal', 'ZTF20aagzzbi', 'ZTF18acqxsyi', 'ZTF19abbxykm', 'ZTF19aakrawk', 'ZTF20aaeopvv', 'ZTF20abgfekk', 'ZTF20aauonld', 'ZTF20aamfpcj', 'ZTF19abrdliq', 'ZTF18aaxavsk', 'ZTF18acutfne', 'ZTF18aavnvmp', 'ZTF19abqsvgf', 'ZTF20aaoldej', 'ZTF19acvrigb', 'ZTF19abpzpqd', 'ZTF20aamerev', 'ZTF20aaurgib', 'ZTF20abefzfc', 'ZTF18aaxokeg', 'ZTF18aapqwyv', 'ZTF20aavhyel', 'ZTF19abaejrh', 'ZTF19abpxttd', 'ZTF19aapdkza', 'ZTF20aazstdx', 'ZTF19abopyyu', 'ZTF18aaydmkh', 'ZTF19aailvhf', 'ZTF19abfsxpw', 'ZTF19abhzdjp', 'ZTF19aathllr', 'ZTF19abyjjxp', 'ZTF18acbxskh', 'ZTF19aamhqej', 'ZTF20aamoaim', 'ZTF19abjslyw', 'ZTF18abzscns', 'ZTF19aaaojck', 'ZTF20abcsbux', 'ZTF19aaqyvdn', 'ZTF19abymukc', 'ZTF19abnishu', 'ZTF19aapbfot', 'ZTF19abinjcy', 'ZTF18aaiykoz', 'ZTF20aafclqz', 'ZTF19aazgdvh', 'ZTF19abmzmom', 'ZTF18acqphpd', 'ZTF19aakiyly', 'ZTF20aaawmxq', 'ZTF19aacivvy', 'ZTF18absspcp', 'ZTF20abgbvgl', 'ZTF19aapxocr', 'ZTF19aamgttu', 'ZTF19abgrcxs', 'ZTF19abkdehm', 'ZTF19abgnbjr', 'ZTF18aawurud', 'ZTF18adbclkd', 'ZTF19aavmlqh', 'ZTF18aaxkfos', 'ZTF18acvrfvv', 'ZTF19abacxod', 'ZTF20aazpyhy', 'ZTF18abimsyv', 'ZTF20aauvjws', 'ZTF20aamaqak', 'ZTF20aammicx', 'ZTF19abqrxhy', 'ZTF19ablesob', 'ZTF19aaydpzi', 'ZTF18acuixmb', 'ZTF20aaieyuw', 'ZTF20abbihor', 'ZTF19aabyppp', 'ZTF19acbhvgi', 'ZTF18abjyjdz', 'ZTF19acbmqpu', 'ZTF18abuhyjv', 'ZTF19acxphhl', 'ZTF20aavvaup', 'ZTF19aauishy', 'ZTF18abhqdpv', 'ZTF20abdsunu', 'ZTF18acqxwgl', 'ZTF19aazudta', 'ZTF18achaqmd', 'ZTF18acenqto', 'ZTF19aadwtoe', 'ZTF19abgurml', 'ZTF19aanhhal', 'ZTF19acxlddi', 'ZTF20aabqamf', 'ZTF18aaylbjm', 'ZTF18acqxcga', 'ZTF18abjtgdo', 'ZTF20aaifyfx', 'ZTF20aatpwaf', 'ZTF19abwscog', 'ZTF19acbtlkz', 'ZTF19acgjnfz', 'ZTF20aadcbux', 'ZTF19aaydpiq', 'ZTF19aacypbw', 'ZTF20aaomtwl', 'ZTF19acaqqke', 'ZTF18abfzhct', 'ZTF19aanfzox', 'ZTF19acbmwtc', 'ZTF20abccojn', 'ZTF19aaflnoi', 'ZTF19abimzvh', 'ZTF20aayknbc', 'ZTF18adaslwa', 'ZTF20aaknzba', 'ZTF19aabyheu', 'ZTF18abcfdzu', 'ZTF18aaisybp', 'ZTF18abdpvnd', 'ZTF20aansktb', 'ZTF20aaxbvkt', 'ZTF19aauxxgk', 'ZTF20aavdgib', 'ZTF18adbyxua', 'ZTF18acmyxfx', 'ZTF18abecbks', 'ZTF18aansqun', 'ZTF19acihlft', 'ZTF18aaxnkos', 'ZTF20aahqbib', 'ZTF19abqsojs', 'ZTF19aauspho', 'ZTF19abixauz', 'ZTF20aavnnkm', 'ZTF19abqyoxt', 'ZTF19aahygro', 'ZTF19abgmkef', 'ZTF19aavnwyt', 'ZTF19aavhwxs', 'ZTF20aaactgu', 'ZTF19acytcoi', 'ZTF19abujhgm', 'ZTF20abbbsfs', 'ZTF19abidfsb', 'ZTF20aauwhfa', 'ZTF20abgbxfm', 'ZTF19aawwlxc', 'ZTF20aahzyml', 'ZTF20aaelulu', 'ZTF18abckutn', 'ZTF20aaiftgi', 'ZTF20aakxzut', 'ZTF19abwswzb', 'ZTF18abfgygp', 'ZTF18abmrhom', 'ZTF19aarjfqe', 'ZTF18abvfecb', 'ZTF18abtfrbf', 'ZTF18abukavn', 'ZTF19aalcwjt', 'ZTF20ababkom', 'ZTF19acojuzv', 'ZTF19aaurxsa', 'ZTF18aarxzmv', 'ZTF20aafgbrf', 'ZTF20aaymbjk', 'ZTF20aabbvcx', 'ZTF18acvweal', 'ZTF18acbwopo', 'ZTF20aabqjht', 'ZTF19aaeoqkk', 'ZTF19abcejrr', 'ZTF19acjuomg', 'ZTF19aavxpbx', 'ZTF19abqxhhr', 'ZTF19abaukyt', 'ZTF19acgdxel', 'ZTF19acsvqrx', 'ZTF19acmblbi', 'ZTF18abxqemv', 'ZTF20aamknxn', 'ZTF20aaivego', 'ZTF18adaylyq', 'ZTF19aaeopgw', 'ZTF18acaeous', 'ZTF19aariwpf', 'ZTF19abmqasg', 'ZTF18abkhbra', 'ZTF20aazooyu', 'ZTF20aanyxvu', 'ZTF19adbryab', 'ZTF19aaojnrx', 'ZTF19aapcxiy', 'ZTF20abciflj', 'ZTF19abiietd', 'ZTF19aaqxcfs', 'ZTF20aaxablt', 'ZTF19abfhszx', 'ZTF20abcqpdj', 'ZTF19aanmzsb', 'ZTF19acgpqxt', 'ZTF19aarfksi', 'ZTF20aatwonv', 'ZTF19abzzgec', 'ZTF19aadnxog', 'ZTF19abzwtiu', 'ZTF18acrflch', 'ZTF19acnfjyw', 'ZTF19abrhjof', 'ZTF18aawozzj', 'ZTF18acmznfc', 'ZTF19aaoyjoz', 'ZTF20aayhacx', 'ZTF19aamhhgu', 'ZTF19abyhxzp', 'ZTF20aahqabk', 'ZTF20aaqhtcd', 'ZTF19aaynsyd', 'ZTF18acpefgk', 'ZTF18acpeemg', 'ZTF19acjerzj', 'ZTF19aakljys', 'ZTF18adazgdh', 'ZTF18aayivoq', 'ZTF19abcupln', 'ZTF20aavhqvo', 'ZTF18acrknyn', 'ZTF18acxhvkv', 'ZTF18abvptts', 'ZTF18abgmcmv', 'ZTF19abajuqh', 'ZTF19aaqhelq', 'ZTF19aaxpjpq', 'ZTF20aaglivt', 'ZTF19achejoc', 'ZTF20aalxlis', 'ZTF19abeyuxt', 'ZTF19aaurhox', 'ZTF18accngee', 'ZTF18acszayr', 'ZTF20abasqfx', 'ZTF19abjnuro', 'ZTF19aazxcvl', 'ZTF18acbxsge', 'ZTF19aaupkev', 'ZTF18aayjyub', 'ZTF19acrdqej', 'ZTF18abuhzfc', 'ZTF19abyflzw', 'ZTF19abjsmmv', 'ZTF18adacicy', 'ZTF20aahjymt', 'ZTF20aaosoct', 'ZTF20aabqisb', 'ZTF19acshkft', 'ZTF19aadnxat', 'ZTF20abbbumr', 'ZTF19aanxnkd', 'ZTF19aamsnhu', 'ZTF19abzsogy', 'ZTF18abpttky', 'ZTF18acmvcme', 'ZTF18aaqvuhl', 'ZTF20aaawbkz', 'ZTF18aaaqexr', 'ZTF19aanhlzn', 'ZTF19aanfnvl', 'ZTF20aaghoqz', 'ZTF19aajwdqt', 'ZTF20aaifyvz', 'ZTF20aavpyxo', 'ZTF19acxlylb', 'ZTF19acignlo', 'ZTF20aaezizk', 'ZTF18abtkqkb', 'ZTF20aauvbez', 'ZTF19acyogrm', 'ZTF20aapjiwl', 'ZTF18abshezu', 'ZTF19aboxjlj', 'ZTF19aakssnv', 'ZTF19achaspq', 'ZTF19adbmewx', 'ZTF20aaxvzja', 'ZTF20aatqesi', 'ZTF20aamdqiz', 'ZTF19abdkgwo', 'ZTF19aaziick', 'ZTF20aalbjqh', 'ZTF19ackjszs', 'ZTF19aboqpry', 'ZTF18ablqlzp', 'ZTF19ablovot', 'ZTF19acxpqgh', 'ZTF19abwouqp', 'ZTF20aaivvwa', 'ZTF18aaqkdwu', 'ZTF19adcdgca', 'ZTF20aahggbm', 'ZTF19aassqix', 'ZTF19acjwdnu', 'ZTF19achetvw', 'ZTF19abxfhrq', 'ZTF20aaznpor', 'ZTF19aatmkll', 'ZTF18adbktyj', 'ZTF20aahpwym', 'ZTF19aczkjxn', 'ZTF19acaotrk', 'ZTF19aamwhat', 'ZTF19abjpntj', 'ZTF20aazrxef', 'ZTF18abadjhx', 'ZTF19aazdiwq', 'ZTF19abqmpsr', 'ZTF19acxnemy', 'ZTF19abqrrto', 'ZTF19abqwtfu', 'ZTF18acbufud', 'ZTF19acvmcdd', 'ZTF18abcyilc', 'ZTF19acgrbeb', 'ZTF19abyvauj', 'ZTF19acazbqm', 'ZTF20aaurexl', 'ZTF19aawlkjx', 'ZTF19abgsyrp', 'ZTF20abegate', 'ZTF20aaoojli', 'ZTF18acpeesd', 'ZTF20aafcjln', 'ZTF18acbznkf', 'ZTF18acwvcbz', 'ZTF20aapycrh', 'ZTF19acfwynw', 'ZTF20aazsyvu', 'ZTF20aaxagnm', 'ZTF18adbadqp', 'ZTF19aawqckx', 'ZTF19abqgwuy', 'ZTF19aaycrgf', 'ZTF20abefbnz', 'ZTF18acvwchp', 'ZTF18abucvbf', 'ZTF19acgxbwo', 'ZTF20aaurucm', 'ZTF18adachwf', 'ZTF20abawntz', 'ZTF19abfdsbu', 'ZTF18abobkii', 'ZTF19adcdtyy', 'ZTF19aaktpns', 'ZTF19acigkma', 'ZTF20aatznro', 'ZTF20abffaxl', 'ZTF20aavnnqo', 'ZTF18aczdtgn', 'ZTF18abtqevs', 'ZTF18aaiiigm', 'ZTF18aaxvpsw', 'ZTF19abudjie', 'ZTF19abvanim', 'ZTF20aadvbni', 'ZTF20aavnnat', 'ZTF20aacbwbm', 'ZTF18aangpkx']

# %%
a = []
for o in o_objs:
    if not o in p_objs:
        a.append(o)

print(len(a))
print(a)
# Out:
# 315
# ...
