# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module

# %%
from flamingchoripan.files import search_for_filedirs
from lchandler import C_

root_folder = '../../surveys-save'
filedirs = search_for_filedirs(root_folder)
filedirs
# Out:
# ['../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=spm-mcmc-fstw.splcds',
#  '../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe.splcds',
#  '../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=bspline-fstw.splcds',
#  '../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=spm-mle-estw.splcds',
#  '../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=spm-mle-fstw.splcds',
#  '../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe.ralcds',
#  '../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=spm-mcmc-estw.splcds',
#  '../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=linear-fstw.splcds']

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle, get_dict_from_filedir

filedir = '../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe~method=linear-fstw.splcds'
#filedir = '../../surveys-save/survey=alerceZTFv7.1~bands=gr~mode=onlySNe.ralcds'
filedict = get_dict_from_filedir(filedir)
root_folder = filedict['_rootdir']
cfilename = filedict['_cfilename']
survey = filedict['survey']
lcdataset = load_pickle(filedir)
print(lcdataset)
# Out:
# LCDataset:
# [outliers - samples 10]
# (.) obs_samples=541 - min_len=14 - max_dur=408.0[days] - dur(p50)=133.8[days] - cadence(p50)=1.0[days]
# (g) obs_samples=260 - min_len=6 - max_dur=408.0[days] - dur(p50)=133.8[days] - cadence(p50)=3.0[days]
# (r) obs_samples=281 - min_len=8 - max_dur=376.0[days] - dur(p50)=128.7[days] - cadence(p50)=3.0[days]
#    |█▌      | SLSN - 2/10 (20.00%)
#    |████    | SNII-b-n - 5/10 (50.00%)
#    |▊       | SNIa - 1/10 (10.00%)
#    |█▌      | SNIbc - 2/10 (20.00%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [faint - samples 48]
# (.) obs_samples=1,107 - min_len=7 - max_dur=298.1[days] - dur(p50)=40.5[days] - cadence(p50)=1.0[days]
# (g) obs_samples=450 - min_len=0 - max_dur=221.7[days] - dur(p50)=28.0[days] - cadence(p50)=2.9[days]
# (r) obs_samples=657 - min_len=4 - max_dur=298.1[days] - dur(p50)=38.9[days] - cadence(p50)=2.9[days]
#    |█▏      | SLSN - 7/48 (14.58%)
#    |██▌     | SNII-b-n - 15/48 (31.25%)
#    |███▊    | SNIa - 23/48 (47.92%)
#    |▌       | SNIbc - 3/48 (6.25%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [raw - samples 1,940]
# (.) obs_samples=53,326 - min_len=6 - max_dur=538.8[days] - dur(p50)=53.0[days] - cadence(p50)=1.0[days]
# (g) obs_samples=23,566 - min_len=0 - max_dur=538.7[days] - dur(p50)=39.0[days] - cadence(p50)=3.0[days]
# (r) obs_samples=29,760 - min_len=0 - max_dur=538.7[days] - dur(p50)=51.0[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 22/1,940 (1.13%)
#    |█▍      | SNII-b-n - 346/1,940 (17.84%)
#    |██████  | SNIa - 1,477/1,940 (76.13%)
#    |▍       | SNIbc - 95/1,940 (4.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [0@train - samples 1,164]
# (.) obs_samples=31,408 - min_len=6 - max_dur=538.8[days] - dur(p50)=53.8[days] - cadence(p50)=1.1[days]
# (g) obs_samples=13,909 - min_len=0 - max_dur=538.7[days] - dur(p50)=39.0[days] - cadence(p50)=3.0[days]
# (r) obs_samples=17,499 - min_len=0 - max_dur=538.7[days] - dur(p50)=51.8[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 13/1,164 (1.12%)
#    |█▍      | SNII-b-n - 208/1,164 (17.87%)
#    |██████  | SNIa - 886/1,164 (76.12%)
#    |▍       | SNIbc - 57/1,164 (4.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [0@val - samples 387]
# (.) obs_samples=11,002 - min_len=7 - max_dur=422.0[days] - dur(p50)=52.9[days] - cadence(p50)=1.0[days]
# (g) obs_samples=4,796 - min_len=0 - max_dur=421.9[days] - dur(p50)=40.0[days] - cadence(p50)=3.0[days]
# (r) obs_samples=6,206 - min_len=0 - max_dur=416.0[days] - dur(p50)=50.9[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 4/387 (1.03%)
#    |█▍      | SNII-b-n - 69/387 (17.83%)
#    |██████  | SNIa - 295/387 (76.23%)
#    |▍       | SNIbc - 19/387 (4.91%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [0@test - samples 389]
# (.) obs_samples=10,846 - min_len=6 - max_dur=443.9[days] - dur(p50)=52.1[days] - cadence(p50)=1.0[days]
# (g) obs_samples=4,836 - min_len=0 - max_dur=443.9[days] - dur(p50)=39.1[days] - cadence(p50)=3.0[days]
# (r) obs_samples=6,010 - min_len=0 - max_dur=443.9[days] - dur(p50)=49.9[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 5/389 (1.29%)
#    |█▍      | SNII-b-n - 69/389 (17.74%)
#    |██████  | SNIa - 296/389 (76.09%)
#    |▍       | SNIbc - 19/389 (4.88%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [1@train - samples 1,163]
# (.) obs_samples=31,375 - min_len=6 - max_dur=538.8[days] - dur(p50)=53.0[days] - cadence(p50)=1.1[days]
# (g) obs_samples=13,784 - min_len=0 - max_dur=538.7[days] - dur(p50)=38.0[days] - cadence(p50)=3.0[days]
# (r) obs_samples=17,591 - min_len=0 - max_dur=538.7[days] - dur(p50)=51.8[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 13/1,163 (1.12%)
#    |█▍      | SNII-b-n - 208/1,163 (17.88%)
#    |██████  | SNIa - 885/1,163 (76.10%)
#    |▍       | SNIbc - 57/1,163 (4.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [1@val - samples 387]
# (.) obs_samples=10,952 - min_len=6 - max_dur=443.9[days] - dur(p50)=52.9[days] - cadence(p50)=1.0[days]
# (g) obs_samples=4,890 - min_len=0 - max_dur=443.9[days] - dur(p50)=39.9[days] - cadence(p50)=3.0[days]
# (r) obs_samples=6,062 - min_len=0 - max_dur=443.9[days] - dur(p50)=50.9[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 4/387 (1.03%)
#    |█▍      | SNII-b-n - 69/387 (17.83%)
#    |██████  | SNIa - 295/387 (76.23%)
#    |▍       | SNIbc - 19/387 (4.91%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [1@test - samples 389]
# (.) obs_samples=10,932 - min_len=8 - max_dur=430.8[days] - dur(p50)=52.0[days] - cadence(p50)=1.0[days]
# (g) obs_samples=4,869 - min_len=0 - max_dur=396.9[days] - dur(p50)=39.9[days] - cadence(p50)=3.0[days]
# (r) obs_samples=6,063 - min_len=0 - max_dur=430.8[days] - dur(p50)=50.0[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 5/389 (1.29%)
#    |█▍      | SNII-b-n - 69/389 (17.74%)
#    |██████  | SNIa - 296/389 (76.09%)
#    |▍       | SNIbc - 19/389 (4.88%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [2@train - samples 1,163]
# (.) obs_samples=32,110 - min_len=6 - max_dur=538.8[days] - dur(p50)=52.9[days] - cadence(p50)=1.0[days]
# (g) obs_samples=14,143 - min_len=0 - max_dur=538.7[days] - dur(p50)=38.0[days] - cadence(p50)=3.0[days]
# (r) obs_samples=17,967 - min_len=0 - max_dur=538.7[days] - dur(p50)=51.0[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 13/1,163 (1.12%)
#    |█▍      | SNII-b-n - 208/1,163 (17.88%)
#    |██████  | SNIa - 885/1,163 (76.10%)
#    |▍       | SNIbc - 57/1,163 (4.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [2@val - samples 387]
# (.) obs_samples=10,909 - min_len=8 - max_dur=430.8[days] - dur(p50)=53.0[days] - cadence(p50)=1.0[days]
# (g) obs_samples=4,852 - min_len=0 - max_dur=396.9[days] - dur(p50)=40.8[days] - cadence(p50)=3.0[days]
# (r) obs_samples=6,057 - min_len=0 - max_dur=430.8[days] - dur(p50)=50.0[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 4/387 (1.03%)
#    |█▍      | SNII-b-n - 69/387 (17.83%)
#    |██████  | SNIa - 295/387 (76.23%)
#    |▍       | SNIbc - 19/387 (4.91%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [2@test - samples 389]
# (.) obs_samples=10,233 - min_len=6 - max_dur=347.1[days] - dur(p50)=53.1[days] - cadence(p50)=1.9[days]
# (g) obs_samples=4,545 - min_len=0 - max_dur=310.1[days] - dur(p50)=39.4[days] - cadence(p50)=3.0[days]
# (r) obs_samples=5,688 - min_len=0 - max_dur=334.2[days] - dur(p50)=51.0[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 5/389 (1.29%)
#    |█▍      | SNII-b-n - 69/389 (17.74%)
#    |██████  | SNIa - 296/389 (76.09%)
#    |▍       | SNIbc - 19/389 (4.88%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [3@train - samples 1,163]
# (.) obs_samples=32,846 - min_len=6 - max_dur=443.9[days] - dur(p50)=52.9[days] - cadence(p50)=1.0[days]
# (g) obs_samples=14,514 - min_len=0 - max_dur=443.9[days] - dur(p50)=39.9[days] - cadence(p50)=3.0[days]
# (r) obs_samples=18,332 - min_len=0 - max_dur=443.9[days] - dur(p50)=50.0[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 13/1,163 (1.12%)
#    |█▍      | SNII-b-n - 208/1,163 (17.88%)
#    |██████  | SNIa - 885/1,163 (76.10%)
#    |▍       | SNIbc - 57/1,163 (4.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [3@val - samples 387]
# (.) obs_samples=10,084 - min_len=6 - max_dur=347.1[days] - dur(p50)=53.0[days] - cadence(p50)=1.9[days]
# (g) obs_samples=4,499 - min_len=0 - max_dur=310.1[days] - dur(p50)=39.0[days] - cadence(p50)=3.0[days]
# (r) obs_samples=5,585 - min_len=0 - max_dur=334.2[days] - dur(p50)=51.0[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 4/387 (1.03%)
#    |█▍      | SNII-b-n - 69/387 (17.83%)
#    |██████  | SNIa - 295/387 (76.23%)
#    |▍       | SNIbc - 19/387 (4.91%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [3@test - samples 389]
# (.) obs_samples=10,320 - min_len=6 - max_dur=538.8[days] - dur(p50)=53.9[days] - cadence(p50)=1.1[days]
# (g) obs_samples=4,524 - min_len=0 - max_dur=538.7[days] - dur(p50)=37.0[days] - cadence(p50)=3.0[days]
# (r) obs_samples=5,796 - min_len=0 - max_dur=538.7[days] - dur(p50)=52.9[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 5/389 (1.29%)
#    |█▍      | SNII-b-n - 69/389 (17.74%)
#    |██████  | SNIa - 296/389 (76.09%)
#    |▍       | SNIbc - 19/389 (4.88%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [4@train - samples 1,164]
# (.) obs_samples=32,022 - min_len=6 - max_dur=443.9[days] - dur(p50)=52.9[days] - cadence(p50)=1.0[days]
# (g) obs_samples=14,236 - min_len=0 - max_dur=443.9[days] - dur(p50)=39.9[days] - cadence(p50)=3.0[days]
# (r) obs_samples=17,786 - min_len=0 - max_dur=443.9[days] - dur(p50)=50.8[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 13/1,164 (1.12%)
#    |█▍      | SNII-b-n - 208/1,164 (17.87%)
#    |██████  | SNIa - 886/1,164 (76.12%)
#    |▍       | SNIbc - 57/1,164 (4.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [4@val - samples 387]
# (.) obs_samples=10,154 - min_len=6 - max_dur=538.8[days] - dur(p50)=53.9[days] - cadence(p50)=1.1[days]
# (g) obs_samples=4,465 - min_len=0 - max_dur=538.7[days] - dur(p50)=37.0[days] - cadence(p50)=3.0[days]
# (r) obs_samples=5,689 - min_len=0 - max_dur=538.7[days] - dur(p50)=52.9[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 4/387 (1.03%)
#    |█▍      | SNII-b-n - 69/387 (17.83%)
#    |██████  | SNIa - 295/387 (76.23%)
#    |▍       | SNIbc - 19/387 (4.91%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [4@test - samples 389]
# (.) obs_samples=11,079 - min_len=7 - max_dur=422.0[days] - dur(p50)=52.9[days] - cadence(p50)=1.0[days]
# (g) obs_samples=4,838 - min_len=0 - max_dur=421.9[days] - dur(p50)=39.9[days] - cadence(p50)=3.0[days]
# (r) obs_samples=6,241 - min_len=0 - max_dur=416.0[days] - dur(p50)=51.8[days] - cadence(p50)=3.0[days]
#    |        | SLSN - 5/389 (1.29%)
#    |█▍      | SNII-b-n - 69/389 (17.74%)
#    |██████  | SNIa - 296/389 (76.09%)
#    |▍       | SNIbc - 19/389 (4.88%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [0@train.linear-fstw - samples 13,968]
# (.) obs_samples=369,520 - min_len=6 - max_dur=538.1[days] - dur(p50)=48.0[days] - cadence(p50)=2.0[days]
# (g) obs_samples=163,335 - min_len=0 - max_dur=538.0[days] - dur(p50)=32.0[days] - cadence(p50)=2.0[days]
# (r) obs_samples=206,185 - min_len=0 - max_dur=538.0[days] - dur(p50)=46.0[days] - cadence(p50)=2.0[days]
#    |        | SLSN - 156/13,968 (1.12%)
#    |█▍      | SNII-b-n - 2,496/13,968 (17.87%)
#    |██████  | SNIa - 10,632/13,968 (76.12%)
#    |▍       | SNIbc - 684/13,968 (4.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [1@train.linear-fstw - samples 13,956]
# (.) obs_samples=367,661 - min_len=6 - max_dur=538.0[days] - dur(p50)=48.0[days] - cadence(p50)=2.0[days]
# (g) obs_samples=161,521 - min_len=0 - max_dur=538.0[days] - dur(p50)=32.0[days] - cadence(p50)=2.0[days]
# (r) obs_samples=206,140 - min_len=0 - max_dur=538.0[days] - dur(p50)=44.0[days] - cadence(p50)=2.0[days]
#    |        | SLSN - 156/13,956 (1.12%)
#    |█▍      | SNII-b-n - 2,496/13,956 (17.88%)
#    |██████  | SNIa - 10,620/13,956 (76.10%)
#    |▍       | SNIbc - 684/13,956 (4.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [2@train.linear-fstw - samples 13,956]
# (.) obs_samples=374,324 - min_len=6 - max_dur=538.3[days] - dur(p50)=48.0[days] - cadence(p50)=1.9[days]
# (g) obs_samples=164,851 - min_len=0 - max_dur=538.0[days] - dur(p50)=32.0[days] - cadence(p50)=2.0[days]
# (r) obs_samples=209,473 - min_len=0 - max_dur=538.0[days] - dur(p50)=44.0[days] - cadence(p50)=2.0[days]
#    |        | SLSN - 156/13,956 (1.12%)
#    |█▍      | SNII-b-n - 2,496/13,956 (17.88%)
#    |██████  | SNIa - 10,620/13,956 (76.10%)
#    |▍       | SNIbc - 684/13,956 (4.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [3@train.linear-fstw - samples 13,956]
# (.) obs_samples=383,110 - min_len=6 - max_dur=442.9[days] - dur(p50)=48.0[days] - cadence(p50)=1.9[days]
# (g) obs_samples=169,010 - min_len=0 - max_dur=442.0[days] - dur(p50)=32.0[days] - cadence(p50)=2.0[days]
# (r) obs_samples=214,100 - min_len=0 - max_dur=442.0[days] - dur(p50)=44.0[days] - cadence(p50)=2.0[days]
#    |        | SLSN - 156/13,956 (1.12%)
#    |█▍      | SNII-b-n - 2,496/13,956 (17.88%)
#    |██████  | SNIa - 10,620/13,956 (76.10%)
#    |▍       | SNIbc - 684/13,956 (4.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [4@train.linear-fstw - samples 13,968]
# (.) obs_samples=374,217 - min_len=6 - max_dur=443.6[days] - dur(p50)=47.4[days] - cadence(p50)=2.0[days]
# (g) obs_samples=166,272 - min_len=0 - max_dur=442.0[days] - dur(p50)=34.0[days] - cadence(p50)=2.0[days]
# (r) obs_samples=207,945 - min_len=0 - max_dur=442.0[days] - dur(p50)=44.0[days] - cadence(p50)=2.0[days]
#    |        | SLSN - 156/13,968 (1.12%)
#    |█▍      | SNII-b-n - 2,496/13,968 (17.87%)
#    |██████  | SNIa - 10,632/13,968 (76.12%)
#    |▍       | SNIbc - 684/13,968 (4.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
import flamingchoripan.lists as lists
from flamingchoripan.cuteplots.utils import save_fig
import matplotlib.pyplot as plt
from lchandler.plots.lc import plot_lightcurve
from flamingchoripan.files import save_time_stamp

figsize = (12,5)
lcset_names = lcdataset.get_lcset_names()
for lcset_name in lcset_names:
    lcset = lcdataset[lcset_name]
    for lcobj_name in lcset.get_lcobj_names():
        fig, ax = plt.subplots(1,1, figsize=figsize)
        lcobj = lcset[lcobj_name]
        c = lcset.class_names[lcobj.y]
        for kb,b in enumerate(lcset.band_names):
            plot_lightcurve(ax, lcobj, b, label=f'{b} obs')
        title = f'survey={lcset.survey}-{"".join(lcset.band_names)} - obj={lcobj_name} [{lcset.class_names[lcobj.y]}]'
        ax.set_title(title)
        ax.set_xlabel('time [days]')
        ax.set_ylabel('observations [flux]')
        ax.grid(alpha=0.5)
        ax.legend()
        save_filedir = f'../save/{cfilename}/{lcset_name}/{c}/{lcobj_name}.png'
        save_fig(save_filedir, fig)
        save_time_stamp(f'../save/{cfilename}')
        #break
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-3204196df90a>", line 12, in <module>
#     fig, ax = plt.subplots(1,1, figsize=figsize)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/pyplot.py", line 1212, in subplots
#     gridspec_kw=gridspec_kw)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/figure.py", line 1575, in subplots
#     axarr[row, col] = self.add_subplot(gs[row, col], **subplot_kw)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/figure.py", line 1414, in add_subplot
#     a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axes/_subplots.py", line 69, in __init__
#     self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axes/_base.py", line 495, in __init__
#     self.cla()
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axes/_base.py", line 1045, in cla
#     self.grid(False)  # Disable grid on init to use rcParameter
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axes/_base.py", line 2787, in grid
#     self.yaxis.grid(b, which=which, **kwargs)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py", line 1477, in grid
#     **gridkw)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py", line 888, in set_tick_params
#     for tick in self.majorTicks:
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py", line 670, in __get__
#     instance.majorTicks.append(tick)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py", line 669, in __get__
#     tick = instance._get_tick(major=True)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py", line 2223, in _get_tick
#     return YTick(self.axes, 0, '', major=major, **tick_kw)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py", line 162, in __init__
#     self.label2 = self._get_text2()
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py", line 564, in _get_text2
#     fontproperties=font_manager.FontProperties(size=self._labelsize),
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/font_manager.py", line 650, in __init__
#     self.set_style(style)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/font_manager.py", line 763, in set_style
#     cbook._check_in_list(['normal', 'italic', 'oblique'], style=style)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/cbook/__init__.py", line 2180, in _check_in_list
#     def _check_in_list(values, **kwargs):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/posixpath.py", line 428, in _joinrealpath
#     newpath = join(path, name)
#   File "/home/tesla/anaconda3/envs/lchandler/lib/python3.7/posixpath.py", line 92, in join
#     path += sep + b
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-4-3204196df90a> in <module>
#      11     for lcobj_name in lcset.get_lcobj_names():
# ---> 12         fig, ax = plt.subplots(1,1, figsize=figsize)
#      13         lcobj = lcset[lcobj_name]
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1211                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1212                        gridspec_kw=gridspec_kw)
#    1213     return fig, axs
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1574                 subplot_kw["sharey"] = shared_with[sharey]
# -> 1575                 axarr[row, col] = self.add_subplot(gs[row, col], **subplot_kw)
#    1576
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      68         # _axes_class is set in the subplot_class_factory
# ---> 69         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      70         # add a layout box to this, for both the full axis, and the poss
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     494         self._connected = {}  # a dict from events to (id, func)
# --> 495         self.cla()
#     496
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axes/_base.py in cla(self)
#    1044
# -> 1045         self.grid(False)  # Disable grid on init to use rcParameter
#    1046         self.grid(self._gridOn, which=rcParams['axes.grid.which'],
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axes/_base.py in grid(self, b, which, axis, **kwargs)
#    2786         if axis in ['y', 'both']:
# -> 2787             self.yaxis.grid(b, which=which, **kwargs)
#    2788
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py in grid(self, b, which, **kwargs)
#    1476             self.set_tick_params(which='major', gridOn=self._gridOnMajor,
# -> 1477                                  **gridkw)
#    1478         self.stale = True
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     887             if which == 'major' or which == 'both':
# --> 888                 for tick in self.majorTicks:
#     889                     tick._apply_params(**kwtrans)
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     669                 tick = instance._get_tick(major=True)
# --> 670                 instance.majorTicks.append(tick)
#     671                 return instance.majorTicks
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     668                 instance.majorTicks = []
# --> 669                 tick = instance._get_tick(major=True)
#     670                 instance.majorTicks.append(tick)
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2222             tick_kw = self._minor_tick_kw
# -> 2223         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2224
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     161         self.label1 = self._get_text1()
# --> 162         self.label2 = self._get_text2()
#     163
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/axis.py in _get_text2(self)
#     563             x=1, y=0,
# --> 564             fontproperties=font_manager.FontProperties(size=self._labelsize),
#     565             color=self._labelcolor,
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/font_manager.py in __init__(self, family, style, variant, weight, stretch, size, fname)
#     649         self.set_family(family)
# --> 650         self.set_style(style)
#     651         self.set_variant(variant)
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/font_manager.py in set_style(self, style)
#     762             style = rcParams['font.style']
# --> 763         cbook._check_in_list(['normal', 'italic', 'oblique'], style=style)
#     764         self._slant = style
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in _check_in_list(values, **kwargs)
#    2179
# -> 2180 def _check_in_list(values, **kwargs):
#    2181     """
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         # in the engines. This should return a list of strings.
# -> 2045                         stb = value._render_traceback_()
#    2046                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2046                     except Exception:
#    2047                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2048                                             value, tb, tb_offset=tb_offset)
#    2049
#    2050                     self._showtraceback(etype, value, stb)
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1435             self.tb = tb
#    1436         return FormattedTB.structured_traceback(
# -> 1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1438
#    1439
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1335             # Verbose modes need a full traceback
#    1336             return VerboseTB.structured_traceback(
# -> 1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1338             )
#    1339         elif mode == 'Minimal':
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1192
#    1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1194                                                                tb_offset)
#    1195
#    1196         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
#    1150
# -> 1151         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1152
#    1153         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/anaconda3/envs/lchandler/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
