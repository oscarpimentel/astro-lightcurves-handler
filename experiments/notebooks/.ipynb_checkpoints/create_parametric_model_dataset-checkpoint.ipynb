# %%
import sys
sys.path.append('../../')
sys.path.append('../../../flaming-choripan')

# %%
from flamingchoripan.files import search_for_filedirs
from lchandler import C_

root_folder = 'save'
filedirs = search_for_filedirs(root_folder, fext=C_.EXT_SPLIT_LIGHTCURVE)
# Out:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# found filedirs: (save)
# (0) - save/alerceZTFv5.1/survey-alerceZTFv5.1_bands-gr_mode-onlySNe_kfid-0.slcd - 1.811[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# filedirs after searching with filters: (save)
# (0) - save/alerceZTFv5.1/survey-alerceZTFv5.1_bands-gr_mode-onlySNe_kfid-0.slcd - 1.811[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.files import get_dict_from_filedir
from lchandler import C_

def load_lcdataset(filename):
    assert filename.split('.')[-1]==C_.EXT_SPLIT_LIGHTCURVE
    return load_pickle(filename)

filedir = 'save/PLAsTiCCv1/survey-PLAsTiCCv1_bands-gr_mode-onlySN_kfid-0.slcd'
filedir = 'save/alerceZTFv5.1/survey-alerceZTFv5.1_bands-gr_mode-onlySNe_kfid-0.slcd'
#filedir = 'save/alerceZTFv5.1/survey-alerceZTFv5.1_bands-gr_mode-onlySNIa_kfid-0.slcd'
#filedir = 'save/FakeSNe/survey-FakeSNe_bands-gr_classes-3_kfid-0.slcd'

filedic = get_dict_from_filedir(filedir)
root_folder = filedic['*rootdir*']
cfilename = filedic['*cfilename*']
lcdataset = load_lcdataset(filedir)
print(lcdataset['raw'].keys())
print(lcdataset['raw'].get_random_lcobj(False).keys())
print(lcdataset)
# Out:
# > loading: save/alerceZTFv5.1/survey-alerceZTFv5.1_bands-gr_mode-onlySNe_kfid-0.slcd
# dict_keys(['data', 'survey', 'description', 'band_names', 'class_names', 'obs_is_flux'])
# dict_keys(['days', 'obs', 'obse', 'y'])
# LCDataset(
# (raw - samples 1,099)
#  - samples: 1,099 - obs samples: 30,346 (g: 12,540 - r: 17,806)
#  - max_length_serial: 205 - max_duration: 578.23[days] - median_cadence: {'g': 3.0078125, 'r': 3.00390625}
#    |▏       | SLSN - 21/1,099 (1.91%)
#    |█████▊  | SNIa - 799/1,099 (72.70%)
#    |▎       | SNIbc - 51/1,099 (4.64%)
#    |█▋      | merSNII - 228/1,099 (20.75%)
# (raw_train - samples 877)
#  - samples: 877 - obs samples: 24,182 (g: 10,010 - r: 14,172)
#  - max_length_serial: 205 - max_duration: 578.23[days] - median_cadence: {'g': 3.0078125, 'r': 3.00390625}
#    |▏       | SLSN - 16/877 (1.82%)
#    |█████▊  | SNIa - 639/877 (72.86%)
#    |▎       | SNIbc - 40/877 (4.56%)
#    |█▋      | merSNII - 182/877 (20.75%)
# (raw_val - samples 222)
#  - samples: 222 - obs samples: 6,164 (g: 2,530 - r: 3,634)
#  - max_length_serial: 108 - max_duration: 489.71[days] - median_cadence: {'g': 3.01171875, 'r': 3.00390625}
#    |▏       | SLSN - 5/222 (2.25%)
#    |█████▊  | SNIa - 160/222 (72.07%)
#    |▍       | SNIbc - 11/222 (4.95%)
#    |█▋      | merSNII - 46/222 (20.72%)
# (train - samples 874)
#  - samples: 874 - obs samples: 22,636 (g: 9,389 - r: 13,247)
#  - max_length_serial: 202 - max_duration: 578.23[days] - median_cadence: {'g': 3.0078125, 'r': 3.00390625}
#    |▏       | SLSN - 16/874 (1.83%)
#    |█████▊  | SNIa - 638/874 (73.00%)
#    |▎       | SNIbc - 39/874 (4.46%)
#    |█▋      | merSNII - 181/874 (20.71%)
# (val - samples 221)
#  - samples: 221 - obs samples: 5,768 (g: 2,393 - r: 3,375)
#  - max_length_serial: 108 - max_duration: 485.73[days] - median_cadence: {'g': 3.01171875, 'r': 3.00390625}
#    |▏       | SLSN - 5/221 (2.26%)
#    |█████▊  | SNIa - 159/221 (71.95%)
#    |▍       | SNIbc - 11/221 (4.98%)
#    |█▋      | merSNII - 46/221 (20.81%)
# )

# %% [markdown]
# # get error distribution fit

# %%
# %load_ext autoreload
# %autoreload 2
from lchandler.synthetic.distr_fitting import ObsErrorConditionalSampler
from lchandler.plots.plots import plot_obse_samplers

set_name = 'train'
band_names = lcdataset[set_name].band_names
obse_sampler_bdict = {b:ObsErrorConditionalSampler(lcdataset, set_name, b) for b in band_names}
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=1)
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
from lchandler.plots.plots import plot_obse_samplers

plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=1, add_samples=1)
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
from lchandler.synthetic.distr_fitting import CurveLengthSampler
from lchandler.plots.plots import plot_length_samplers

set_name = 'train'
band_names = lcdataset[set_name].band_names
offset = 20
length_sampler_bdict = {b:CurveLengthSampler(lcdataset, set_name, b, offset) for b in band_names}
plot_length_samplers(length_sampler_bdict, lcdataset, set_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
from lchandler.synthetic.synthetic_dataset_generators import GEN_CDICT
from lchandler.plots.lc import plot_synthetic_samples

method = 'curve_fit'
method = 'mcmc'
set_name = 'train'
new_bounds = 1
save_rootdir = '/home/opimentel/tesis/astro-lightcurves-handler/save'
save_rootdir = None
synthetic_samples_per_curve = 32

lcset = lcdataset[set_name]
ignored_names = [
    'ZTF18acwvcbz',
    'ZTF18abslpjy',
]
risky_names = [
    'ZTF18aavjcpf',
]
other_names = [
    'ZTF19abajxet',
    'ZTF19aapfnym',
    'ZTF19aadpqnb',
    'ZTF19aaksrlb',
    'ZTF19aariwfe',
    'ZTF18acgvgiq',
    'ZTF19acbihxh',
]
for lcobj_name in ignored_names+risky_names+other_names:
    #lcobj_name = lc_set.get_random_lcobj_name() # random
    lcobj = lcset[lcobj_name]
    band_names = lcset.band_names
    class_names = lcset.class_names
    sne_generator = GEN_CDICT[method](lcobj, class_names, band_names, obse_sampler_bdict, length_sampler_bdict, new_bounds=new_bounds)
    new_lcobjs, new_lcobjs_pm, fit_errors_bdict = sne_generator.sample_curves(synthetic_samples_per_curve)
    plot_kwargs = {
        'fit_errors_bdict':fit_errors_bdict,
        'save_rootdir':save_rootdir,
    }
    plot_synthetic_samples(lcdataset, set_name, method, lcobj_name, new_lcobjs, new_lcobjs_pm, **plot_kwargs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-d2799a9f36fe> in <module>
#      35     class_names = lcset.class_names
#      36     sne_generator = GEN_CDICT[method](lcobj, class_names, band_names, obse_sampler_bdict, length_sampler_bdict, new_bounds=new_bounds)
# ---> 37     new_lcobjs, new_lcobjs_pm, fit_errors_bdict = sne_generator.sample_curves(synthetic_samples_per_curve)
#      38     plot_kwargs = {
#      39         'fit_errors_bdict':fit_errors_bdict,
#
# ~/tesis/astro-lightcurves-handler/lchandler/synthetic/synthetic_curve_generators.py in sample_curves(self, n)
#     304                 fit_errors_bdict = {}
#     305                 for b in self.band_names:
# --> 306                         new_lcobjbs, new_lcobjbs_pm, fit_errors = self.sample_curve_b(b, n)
#     307                         fit_errors_bdict[b] = fit_errors
#     308
#
# ~/tesis/astro-lightcurves-handler/lchandler/synthetic/synthetic_curve_generators.py in sample_curve_b(self, b, n)
#     501                                 pm_args = mcmc_pm_args[idx]
#     502                                 new_lcobjb_pm = mcmc_errors[idx]
# --> 503                                 pm_times = self.get_tmax(pm_args, lcobjb, self.min_obs_bdict[b])
#     504                                 new_lcobjb = self.__sample_curve__(pm_times, pm_args, curve_lengths[kn], lcobjb, b)
#     505                                 new_lcobjb_pm = self.__sample_curve__(pm_times, pm_args, curve_lengths[kn], lcobjb, b, True)
#
# ~/tesis/astro-lightcurves-handler/lchandler/synthetic/synthetic_curve_generators.py in get_tmax(self, pm_args, lcobjb, threshold)
#     103
#     104         def get_tmax(self, pm_args, lcobjb, threshold):
# --> 105                         t0 = pm_args['t0']
#     106                         pm_bounds = self.get_pm_bounds(lcobjb)[self.c]
#     107                         first_day = lcobjb.days[0]
#
# TypeError: list indices must be integers or slices, not str

# %%
# %load_ext autoreload
# %autoreload 2
from lchandler.plots.plots import plot_mcmc_trace

plot_mcmc_trace(sne_generator.mcmc_trace_bdict, 'g')

# %% [markdown]
# # generate synth data

# %%
# %load_ext autoreload
# %autoreload 2
from lchandler.synthetic.synthetic_dataset_generators import generate_synthetic_dataset

sd_kwargs = {
    'synthetic_samples_per_curve':64,
    #'method':'curve_fit',
    'method':'mcmc',
    'ignored_lcobj_names':ignored_names,
    'save_rootdir':'/home/opimentel/tesis/astro-lightcurves-handler/save',
}
errors = generate_synthetic_dataset(lcdataset, 'train', obse_sampler_bdict, length_sampler_bdict, **sd_kwargs)
print(lcdataset)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#   0%|          | 0/874 [?it/s, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19acfwynw]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   0%|          | 3/874 [234.63s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaqrime]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   0%|          | 4/874 [224.71s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18acnnevs]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|          | 5/874 [270.76s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaserwb]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|          | 6/874 [224.89s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aamrais]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|          | 9/874 [233.17s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aalbrgu]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|          | 10/874 [276.74s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18abslpjy]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|▏         | 11/874 [238.05s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abnacvf]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|▏         | 12/874 [241.11s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18acenqto]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 15/874 [211.68s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aanesgt]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 17/874 [237.92s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19acgcshq]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 18/874 [267.07s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19acewotx]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 19/874 [279.36s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abzzhgx]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 21/874 [278.66s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18acmvcme]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 22/874 [311.86s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aayfaum]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 23/874 [276.13s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaripqw]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 24/874 [270.33s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18acuefvt]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-9aa15e0ea561> in <module>
#      15 }
#      16 generate_synthetic_dataset(lcdataset, 'train', obse_sampler_bdict, length_sampler_bdict, **sd_kwargs)
# ---> 17 print(lcdataset)
#
# ~/tesis/astro-lightcurves-handler/lchandler/dataset_classes.py in __repr__(self)
#      50                 txt = 'LCDataset(\n'
#      51                 for lcset_name in self.get_lcset_names():
# ---> 52                         txt += f'({lcset_name} - samples {len(self[lcset_name]):,})\n - {self[lcset_name]}\n'
#      53                 txt += ')'
#      54                 return txt
#
# ~/tesis/astro-lightcurves-handler/lchandler/dataset_classes.py in __repr__(self)
#     217                         txt = f'samples: {len(self):,} - obs samples: {obs_len:,} ({obs_len_txt})\n'
#     218                         max_duration = max([lcobj.get_days_serial_duration() for lcobj in self.get_lcobjs()])
# --> 219                         self.set_diff_parallel('days') # remove after?
#     220                         median_cadence = {}
#     221                         for b in self.band_names:
#
# ~/tesis/astro-lightcurves-handler/lchandler/dataset_classes.py in set_diff_parallel(self, attr)
#     185 		'''
#     186                 for lcobj_name in self.get_lcobj_names():
# --> 187                         self[lcobj_name].set_diff_parallel(attr)
#     188
#     189         def set_log_parallel(self, attr:str):
#
# ~/tesis/astro-lightcurves-handler/lchandler/lc_classes.py in set_diff_parallel(self, attr)
#     373 		'''
#     374                 for b in self.bands:
# --> 375                         self.set_diff_b(b, attr)
#     376
#     377         def set_log_b(self, b:str, attr:str):
#
# KeyboardInterrupt:

# %%
# %load_ext autoreload
# %autoreload 2
from lchandler.plots.plots import plot_obs_obse_scatter

plot_obs_obse_scatter(lcdataset, 'train', 'synth_train')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import flamingchoripan.cutePlots.colors as cc
import flamingchoripan.cutePlots.plots as cplots

figsize = (12,5)
fig, ax = plt.subplots(1, 1, figsize=figsize)
for ks,set_name in enumerate(['synth_train']):
    lcset = lcdataset.get(set_name)
    lcobj_classes = lcset.get_lcobj_classes()
    to_plot = {'class samples':lcobj_classes}
    title = 'class population distribution\n'
    title += f'survey: {lcset.survey} - set: {set_name} - class samples: {len(lcobj_classes):,}'
    plt_kwargs = {
        'fig':fig,
        'ax':ax,
        'ylabel':'' if ks>0 else None,
        'legend_ncol':len(lcset.band_names),
        'title':title,
        'cmap':cc.colorlist_to_cmap([cc.NICE_COLORS_DICT['nice_gray']]),
        'uses_log_scale':0,
    }
    fig, ax = cplots.plot_hist_labels(to_plot, lcset.class_names, **plt_kwargs)
    
fig.tight_layout()
plt.plot()

# %%
# %load_ext autoreload
# %autoreload 2
from src.plots import plot_synthetic_samples

plot_synthetic_samples(lcdataset, 'train', max_samples=1)

# %%
# %load_ext autoreload
# %autoreload 2
from src.umaps import get_fitted_umap, get_transformed_umap

set_name_train = 'train'
set_name_test = 'synth_train'
30
pm_umap_results = get_fitted_umap(lcdataset, set_name_test)
res = get_transformed_umap(lcdataset, pm_umap_results, set_name_train, set_name_test)
pm_args_embd_results_train, pm_args_embd_results_test = res

# %%
# %load_ext autoreload
# %autoreload 2
from src.plots import plot_2Dprojections

for c in [None]+lcdataset.raw.class_names:
    kwargs = {
        'target_class':c,
        #'x_mode':'x_pca',
        'x_mode':'x_umap',
        'x_mode':'x_tsne',
    }
    plot_2Dprojections(lcdataset, set_name_train, pm_args_embd_results_train, set_name_test, pm_args_embd_results_test, **kwargs)

# %%
from flamingchoripan.myUtils.files import load_pickle, save_pickle
from src import C_

assert 0
save_filedir = f'{root_folder}/{cfilename}.{C_.EXT_PARAMETRIC_LIGHTCURVE}'
save_pickle(save_filedir, lcdataset)
