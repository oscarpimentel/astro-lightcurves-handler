# %% [markdown]
# # ALeRCE classes
#
# https://github.com/ZwickyTransientFacility/ztf-avro-alert
#
# 1. **AGN:** Active Galactic Nuclei
# 1. **Blazar:** Blazar
# 1. **CV/Nova:** Cataclysmic Variable Star/Nova
# 1. **Ceph:** Cepheid Variable Star
# 1. **DSCT:** Delta Scuti Star
# 1. **EA:** Eclipsing Algol
# 1. **EB/EW:** Eclipsing Binaries/Eclipsing W Ursa Majoris
# 1. **LPV:** Long Period Variable
# 1. **Periodic-Other:** Periodic-Other
# 1. **QSO:** Quasi-Stellar Object
# 1. **RRL:** RRLyrae Variable Star
# 1. **RSCVn:** RS Canum Venaticorum
# 1. **SLSN:** Super Luminous Supernova
# 1. **SNII:** Supernova II
# 1. **SNIIb:** Supernova IIb
# 1. **SNIIn:** Supernova IIn
# 1. **SNIa:** Supernova Ia
# 1. **SNIbc:** Supernova Ibc
# 1. **TDE:** Tidal disruption event (to remove)
# 1. **YSO:** Young Stellar Object
# 1. **ZZ:** ZZ Ceti Stars (to remove)

# %%
import sys
sys.path.append('../../../')
sys.path.append('../../../../flaming-choripan')

# %%
# %load_ext autoreload
# %autoreload 2
from lchandler.survey_export.alerce_utils import process_df_labels, process_df_detections, keep_only_valid_objs
import numpy as np
import pandas as pd

load_rootdir = '/home/opimentel/tesis/surveys_data'
survey_name = 'alerceZTFv7.1'
uses_corr = 1 # uses_corr=False only can be used with SNe objects
df_index_names = {
    'oid':'oid', # object id
    'oid_det':'objectId', # object id
    'label':'classALeRCE', # object class name
    'ra':'ra',
    'dec':'dec',
    'band':'fid', # band
    'obs_day':'mjd', # days
    'obs':'magpsf_corr' if uses_corr else 'magpsf', # observations
    'obs_error':'sigmapsf_corr' if uses_corr else 'sigmapsf', # observation errors
}
detections_cols = ['objectId', 'fid', 'mjd', df_index_names['obs'], df_index_names['obs_error']]

### load files and processing
detections_df = pd.read_parquet(f'{load_rootdir}/{survey_name}/detections_with_xmatch')
detections_df, det_objs = process_df_detections(detections_df, df_index_names['oid_det'], df_index_names['oid'], detections_cols, uses_corr=uses_corr)
print(f'detections_df - columns: {list(detections_df.columns)} - id: {detections_df.index.name}')

labels_df = pd.read_csv(f'{load_rootdir}/{survey_name}/dfcrossmatches_prioritized_v7.0.1.csv')
labels_df, label_objs = process_df_labels(labels_df, df_index_names['oid'], det_objs)
print(f'labels - columns: {list(labels_df.columns)} - id: {labels_df.index.name}')

### filter
valid_objs = list(set(det_objs) & set(label_objs))
labels_df = keep_only_valid_objs(labels_df, valid_objs)
detections_df = keep_only_valid_objs(detections_df, valid_objs)

### print info
classes = set(labels_df[df_index_names['label']].values)
print('classes:', classes)
# Out:
# detections_df - columns: ['fid', 'mjd', 'magpsf_corr', 'sigmapsf_corr'] - id: oid
# labels - columns: ['classALeRCE', 'ra', 'dec', 'period', 'source', 'id_source', 'class_source', 'separation_arcsec'] - id: oid
# classes: {'SNII', 'NLQSO', 'Blazar', 'Ceph', 'TDE', 'EB/EW', 'CV/Nova', 'RSCVn', 'RRL', 'AGN', 'LPV', 'SNIbc', 'EA', 'NLAGN', 'SLSN', 'Periodic-Other', 'QSO', 'DSCT', 'ZZ', 'SNIIb', 'SNIa', 'SNIIn', 'YSO'}

# %%
detections_df.info()
detections_df[:10]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13119960 entries, ZTF17aaaemke to ZTF20abfpkfh
# Data columns (total 4 columns):
# fid              int64
# mjd              float64
# magpsf_corr      float64
# sigmapsf_corr    float64
# dtypes: float64(3), int64(1)
# memory usage: 500.5+ MB
#               fid           mjd  magpsf_corr  sigmapsf_corr
# oid
# ZTF17aaaemke    1  58700.461042    16.478576       0.008541
# ZTF17aaaemke    1  58754.290857    16.520813     100.000000
# ZTF17aaaemke    1  58763.377998    16.586325       0.024660
# ZTF17aaaemke    1  58718.413889    16.350400     100.000000
# ZTF17aaaemke    1  58372.401910    16.530643       0.014738
# ZTF17aaaemke    1  58679.445093    16.080139     100.000000
# ZTF17aaaemke    1  58510.130151    16.741460       0.026502
# ZTF17aaaemke    1  58736.459699    16.580482       0.025537
# ZTF17aaaemke    1  58789.206968    16.571587     100.000000
# ZTF17aaaemke    1  58482.128333    16.707977       0.000809

# %%
labels_df.info()
labels_df[:10]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 142269 entries, ZTF19abegncu to ZTF18abgqxlw
# Data columns (total 8 columns):
# classALeRCE          142269 non-null object
# ra                   142269 non-null float64
# dec                  142269 non-null float64
# period               79529 non-null object
# source               142269 non-null object
# id_source            142269 non-null object
# class_source         142269 non-null object
# separation_arcsec    142269 non-null float64
# dtypes: float64(3), object(5)
# memory usage: 9.8+ MB
#              classALeRCE          ra        dec period  source  \
# oid
# ZTF19abegncu         AGN  357.296363  -8.941186    NaN  Oh2015
# ZTF19abmposz         AGN   26.670031  -8.354787    NaN  Oh2015
# ZTF18acatykj         AGN  326.479279  12.176132    NaN  Oh2015
# ZTF19aapcxhy         AGN  154.202129  18.723076    NaN  Oh2015
# ZTF18abtyspw         AGN   25.660298   0.087434    NaN  Oh2015
# ZTF18abwtbad         AGN   51.846346   0.739559    NaN  Oh2015
# ZTF18abtmwvo         AGN   46.074050   0.474212    NaN  Oh2015
# ZTF18acvgdfy         AGN  134.407409   5.472596    NaN  Oh2015
# ZTF18aaftbkj         AGN  126.878339  12.906360    NaN  Oh2015
# ZTF19aabvjsi         AGN  132.353298  14.067266    NaN  Oh2015
#
#                           id_source          class_source  separation_arcsec
# oid
# ZTF19abegncu    5.8772718059579e+17  AGN_galaxy_dominated           0.243081
# ZTF19abmposz  5.877271806085038e+17  AGN_galaxy_dominated           0.213990
# ZTF18acatykj  5.877272224729663e+17  AGN_galaxy_dominated           0.300553
# ZTF19aapcxhy  5.877420127343739e+17  AGN_galaxy_dominated           0.227455
# ZTF18abtyspw  5.880155092805878e+17  AGN_galaxy_dominated           0.141792
# ZTF18abwtbad  5.877315136939624e+17  AGN_galaxy_dominated           0.084636
# ZTF18abtmwvo  5.880155098263717e+17  AGN_galaxy_dominated           0.471111
# ZTF18acvgdfy  5.877327033915148e+17  AGN_galaxy_dominated           0.087190
# ZTF18aaftbkj  5.877420621222382e+17  AGN_galaxy_dominated           0.070934
# ZTF19aabvjsi  5.877420137987442e+17  AGN_galaxy_dominated           0.182894

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from lchandler.survey_export.dictionary_creator import LightCurveDictionaryCreator

band_dictionary = {
    'g':1,
    'r':2,
}
args = [survey_name, detections_df, labels_df, band_dictionary, df_index_names]
kwargs = {
    'dataframe_obs_uses_flux':False,
    'zero_point':48.6,
}
lcDictionaryCreator = LightCurveDictionaryCreator(*args, **kwargs)
print(lcDictionaryCreator)
#lcDictionaryCreator.plot_class_distribution(figsize=(13,6), uses_log_scale=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# |██▍                                                                 | AGN - 5,067/142,269 (3.56%)
# |▋                                                                   | Blazar - 1,370/142,269 (0.96%)
# |▍                                                                   | CV/Nova - 956/142,269 (0.67%)
# |▎                                                                   | Ceph - 718/142,269 (0.50%)
# |▍                                                                   | DSCT - 950/142,269 (0.67%)
# |███▊                                                                | EA - 7,956/142,269 (5.59%)
# |███████████████████▏                                                | EB/EW - 40,054/142,269 (28.15%)
# |███████                                                             | LPV - 14,902/142,269 (10.47%)
# |                                                                    | NLAGN - 7/142,269 (0.00%)
# |                                                                    | NLQSO - 114/142,269 (0.08%)
# |▎                                                                   | Periodic-Other - 543/142,269 (0.38%)
# |██████████████▏                                                     | QSO - 29,623/142,269 (20.82%)
# |████████████████▉                                                   | RRL - 35,383/142,269 (24.87%)
# |▋                                                                   | RSCVn - 1,339/142,269 (0.94%)
# |                                                                    | SLSN - 24/142,269 (0.02%)
# |                                                                    | SNII - 198/142,269 (0.14%)
# |                                                                    | SNIIb - 10/142,269 (0.01%)
# |                                                                    | SNIIn - 25/142,269 (0.02%)
# |▍                                                                   | SNIa - 837/142,269 (0.59%)
# |                                                                    | SNIbc - 68/142,269 (0.05%)
# |                                                                    | TDE - 5/142,269 (0.00%)
# |█                                                                   | YSO - 2,114/142,269 (1.49%)
# |                                                                    | ZZ - 6/142,269 (0.00%)

# %%
DF_INVALID_CLASSES = []
DF_SN_LIST = ['SLSN' ,'SNII', 'SNIIb', 'SNIIn', 'SNIa', 'SNIbc']

#mode = 'raw'
#mode = 'simple'
#mode = 'transients'
#mode = 'RRCeph'
mode = 'onlySNe'
#mode = 'onlySNIa'

if mode=='simple':
    invalid_classes = DF_INVALID_CLASSES
    query_classes = []
    to_merge_classes_dic = {'SN':DF_SN_LIST,}
    
elif mode=='onlySNe':
    kwargs = {
        'invalid_classes':[],
        'query_classes':DF_SN_LIST,
        'merge_classes_dict':{
            'merSNII':['SNII', 'SNIIb', 'SNIIn'],
        },
    }
    
elif mode=='onlySNIa':
    kwargs = {
        'invalid_classes':[],
        'query_classes':DF_SN_LIST,
        'merge_classes_dict':{
            'nonSNIa':['SLSN' ,'SNII', 'SNIIb', 'SNIIn', 'SNIbc'],
        },
    }

elif mode=='RRCeph':
    invalid_classes = DF_INVALID_CLASSES
    query_classes = ['RRL','Ceph']
    to_merge_classes_dic = {}

lcDictionaryCreator.update_labels_df(**kwargs)
lcDictionaryCreator.plot_class_distribution(figsize=(5,4), uses_log_scale=True)

# %%
# %load_ext autoreload
# %autoreload 2

description = 'ZTF Alerce'
save_folder = f'/home/opimentel/tesis/astro-lightcurves-handler/save/{survey_name}'
filename_extra_parameters = {
    'mode':mode,
}
kwargs = {
    'band_names':list(band_dictionary.keys()),
    #'to_export_bands':['g','r'],
    'filename_extra_parameters':filename_extra_parameters,
}
raw_lcdataset = lcDictionaryCreator.export_dictionary(description, save_folder, **kwargs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# band_names: ['g', 'r']
# cleaning the DataFrame - samples: 13,119,960
# remove_invalid_bands > samples: 13,118,961
# remove_invalid_classes > samples: 26,612
# remove_negative_obs > samples: 26,612
# save_filedir: /home/opimentel/tesis/astro-lightcurves-handler/save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.rawlcd
# easy_label_dict: {'SLSN': 0, 'SNIa': 1, 'SNIbc': 2, 'merSNII': 3}
# 100%|██████████| 1162/1162 [198.31it/s, obj: ZTF18acbwtnh - y: 1 - c: SNIa - lengths_bdict: {'g': 3, 'r': 3} - correct_samples (any-band>=5): 991]
# > saving: /home/opimentel/tesis/astro-lightcurves-handler/save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.rawlcd

# %%
print(raw_lcdataset)
# Out:
# LCDataset(
# (raw - samples 991)
#  - samples: 991 - obs samples: 26,209 (g: 11,640 - r: 14,569)
#  - max_length_serial: 467 - max_duration: 822.98[days] - median_cadence: {'g': 2.9986862998921424, 'r': 2.978055600076914}
#    |▏       | SLSN - 18/991 (1.82%)
#    |█████▊  | SNIa - 716/991 (72.25%)
#    |▍       | SNIbc - 58/991 (5.85%)
#    |█▌      | merSNII - 199/991 (20.08%)
# )

# %%
import flamingchoripan.lists as lists
import matplotlib.pyplot as plt
from lchandler.plots.lc import plot_lightcurve

lcset = raw_lcdataset['raw']
lcobj, lcobj_name = lcset.get_random_lcobj()
#lcobj_name = 'ZTF18acdvvgx'; lcobj = lcset[lcobj_name]
fig, ax = plt.subplots(1,1, figsize=(12,5))
for kb,b in enumerate(lcset.band_names):
    plot_lightcurve(ax, lcobj, b)
ax.set_title(f'survey: {lcset.survey} - lcobj_name: {lcobj_name} - class: {lcset.class_names[lcobj.y]}')
ax.set_xlabel('days')
ax.set_ylabel('flux')
ax.grid(alpha=0.5)
