# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module

# %%
from flamingchoripan.files import search_for_filedirs
from lchandler import C_

root_folder = '../../surveys-save'
filedirs = search_for_filedirs(root_folder, fext=C_.EXT_SPLIT_LIGHTCURVE)
# Out:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# found filedirs: (../../surveys-save)
# (0) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.splcds - 7.123[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# filedirs after searching with filters: (../../surveys-save)
# (0) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.splcds - 7.123[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.progress_bars import ProgressBar
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.files import get_dict_from_filedir
from lchandler import C_

def load_lcdataset(filedir):
    assert filedir.split('.')[-1]==C_.EXT_SPLIT_LIGHTCURVE
    return load_pickle(filedir)

filedir = '../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.splcds'

filedic = get_dict_from_filedir(filedir)
root_folder = filedic['*rootdir*']
cfilename = filedic['*cfilename*']
survey = filedic['survey']
lcdataset = load_lcdataset(filedir)
print(lcdataset['raw'].keys())
print(lcdataset['raw'].get_random_lcobj(False).keys())
print(lcdataset)
# Out:
# > loading: ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.splcds
# dict_keys(['data', 'survey', 'description', 'band_names', 'class_names', 'obs_is_flux'])
# dict_keys(['days', 'obs', 'obse', 'y', 'synthetic'])
# LCDataset:
# [outliers - samples 6]
# (*) obs_samples: 363 - min_len: 10 - max_dur: 412.9[days] - dur(p50): 221.7[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 178 - min_len: 3 - max_dur: 408.0[days] - dur(p50): 220.2[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 185 - min_len: 7 - max_dur: 376.0[days] - dur(p50): 165.2[days] - cadence(p50): 3.0[days]
#    |██▋     | SLSN - 2/6 (33.33%)
#    |        | SNIa - 0/6 (0.00%)
#    |████    | SNIbc - 3/6 (50.00%)
#    |█▎      | allSNII - 1/6 (16.67%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [raw - samples 2,041]
# (*) obs_samples: 64,811 - min_len: 6 - max_dur: 538.8[days] - dur(p50): 52.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 28,173 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 38.8[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 36,638 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 50.8[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 31/2,041 (1.52%)
#    |██████  | SNIa - 1,534/2,041 (75.16%)
#    |▍       | SNIbc - 100/2,041 (4.90%)
#    |█▍      | allSNII - 376/2,041 (18.42%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [train - samples 1,302]
# (*) obs_samples: 42,282 - min_len: 3 - max_dur: 538.8[days] - dur(p50): 53.0[days] - cadence(p50): 0.9[days]
# (g) obs_samples: 18,492 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 39.0[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 23,790 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 51.0[days] - cadence(p50): 2.9[days]
#    |        | SLSN - 19/1,302 (1.46%)
#    |██████  | SNIa - 980/1,302 (75.27%)
#    |▍       | SNIbc - 64/1,302 (4.92%)
#    |█▍      | allSNII - 239/1,302 (18.36%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [val - samples 325]
# (*) obs_samples: 9,898 - min_len: 6 - max_dur: 422.0[days] - dur(p50): 52.0[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 4,305 - min_len: 0 - max_dur: 421.9[days] - dur(p50): 37.0[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 5,593 - min_len: 0 - max_dur: 416.0[days] - dur(p50): 49.0[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 4/325 (1.23%)
#    |██████  | SNIa - 245/325 (75.38%)
#    |▍       | SNIbc - 16/325 (4.92%)
#    |█▍      | allSNII - 60/325 (18.46%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [test - samples 412]
# (*) obs_samples: 11,696 - min_len: 6 - max_dur: 388.0[days] - dur(p50): 51.4[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 5,017 - min_len: 0 - max_dur: 370.0[days] - dur(p50): 38.0[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 6,679 - min_len: 2 - max_dur: 387.9[days] - dur(p50): 49.9[days] - cadence(p50): 3.0[days]
#    |▏       | SLSN - 8/412 (1.94%)
#    |█████▉  | SNIa - 308/412 (74.76%)
#    |▍       | SNIbc - 20/412 (4.85%)
#    |█▍      | allSNII - 76/412 (18.45%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [train+val - samples 1,627]
# (*) obs_samples: 52,180 - min_len: 3 - max_dur: 538.8[days] - dur(p50): 52.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 22,797 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 38.9[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 29,383 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 50.9[days] - cadence(p50): 2.9[days]
#    |        | SLSN - 23/1,627 (1.41%)
#    |██████  | SNIa - 1,225/1,627 (75.29%)
#    |▍       | SNIbc - 80/1,627 (4.92%)
#    |█▍      | allSNII - 299/1,627 (18.38%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
import flamingchoripan.lists as lists
import matplotlib.pyplot as plt
from lchandler.plots.lc import plot_lightcurve

lcset = lcdataset['outliers']
for lcobj_name in lcset.get_lcobj_names():
    fig, ax = plt.subplots(1,1, figsize=(12,5))
    lcobj = lcset[lcobj_name]
    for kb,b in enumerate(lcset.band_names):
        plot_lightcurve(ax, lcobj, b)
    ax.set_title(f'survey: {lcset.survey} - obj: {lcobj_name} - class: {lcset.class_names[lcobj.y]}')
    ax.set_xlabel('days')
    ax.set_ylabel('obs[flux]')
    ax.grid(alpha=0.5)
